# %%
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, Float

from sqlalchemy.ext.declarative import declarative_base
# Create a base class for declarating class definitions to produce Table objects
Base = declarative_base()
# Out:
# /var/folders/d2/rs9l0yts25jd2cswktf_sr9c0000gn/T/ipykernel_64634/3836882636.py:6: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
class FantasyFootball(Base):
    __tablename__ = 'fantasydata'
    
    id = Column(Integer, primary_key=True)
    Week = Column(Float)
    Name = Column(String)
    Position = Column(String)
    Year = Column(Integer)
    Game = Column(String)
    FantasyPoints = Column(Integer)
    PassingYards = Column(Float)
    PassingTDs = Column(Float)
    Ints = Column(Integer)
    RushAttempts = Column(Integer)
    RushYards = Column(Integer)
    Fumbles = Column(Integer)
    RushTDs = Column(Float)
    Receptions = Column(Float)
    ReceivingYards = Column(Float)
    ReceivingTDs = Column(Float)

# %%
engine = create_engine('sqlite:///football.db')
Base.metadata.create_all(engine)

# %%
from sqlalchemy.orm import Session
from sqlalchemy import func
session = Session(bind=engine)

# %%
results = session.query(FantasyFootball.Name, FantasyFootball.Year, func.sum(FantasyFootball.FantasyPoints).label('Fantasy_Points'), func.sum(FantasyFootball.PassingYards).label('Passing_yards'),func.sum(FantasyFootball.PassingTDs).label('Passing_TDs'),func.sum(FantasyFootball.RushTDs).label('Rush_TDs')) \
                 .filter(FantasyFootball.Position == 'QB') \
                 .group_by(FantasyFootball.Name, FantasyFootball.Year).order_by(FantasyFootball.Name,FantasyFootball.Year) \
                 .all()

# %%
results
# Out:
# [('A.J. McCarron', '2019', 16.0, 225.0, 0.0, 1),
#  ('A.J. McCarron', '2020', 0.0, 20.0, 0.0, 0),
#  ('A.J. McCarron', '2023', 0.0, 19.0, 0.0, 0),
#  ('Aaron Rodgers', '2019', 322.0, 4002.0, 26.0, 1),
#  ('Aaron Rodgers', '2020', 469.0, 4299.0, 48.0, 3),
#  ('Aaron Rodgers', '2021', 394.0, 4115.0, 37.0, 3),
#  ('Aaron Rodgers', '2022', 286.0, 3695.0, 26.0, 1),
#  ('Aaron Rodgers', '2023', 0.0, 0.0, 0.0, 0),
#  ("Aidan O'Connell", '2023', 144.0, 2218.0, 12.0, 1),
#  ('Alex Smith', '2020', 79.0, 1582.0, 6.0, 0),
#  ('Alex Tanney', '2019', 0.0, 1.0, 0.0, 0),
#  ('Andy Dalton', '2019', 232.0, 3494.0, 16.0, 4),
#  ('Andy Dalton', '2020', 158.0, 2170.0, 14.0, 0),
#  ('Andy Dalton', '2021', 96.0, 1515.0, 8.0, 0),
#  ('Andy Dalton', '2022', 204.0, 2871.0, 18.0, 0),
#  ('Andy Dalton', '2023', 27.0, 361.0, 2.0, 0),
#  ('Anthony Brown', '2022', 6.0, 302.0, 0.0, 0),
#  ('Anthony Richardson', '2023', 76.0, 577.0, 3.0, 4),
#  ('Bailey Zappe', '2022', 51.0, 781.0, 5.0, 0),
#  ('Bailey Zappe', '2023', 76.0, 1272.0, 6.0, 1),
#  ('Baker Mayfield', '2019', 262.0, 3827.0, 22.0, 3),
#  ('Baker Mayfield', '2020', 288.0, 3563.0, 26.0, 1),
#  ('Baker Mayfield', '2021', 205.0, 3010.0, 17.0, 1),
#  ('Baker Mayfield', '2022', 134.0, 2163.0, 10.0, 1),
#  ('Baker Mayfield', '2023', 319.0, 4044.0, 28.0, 1),
#  ('Ben DiNucci', '2020', 8.0, 219.0, 0.0, 0),
#  ('Ben Roethlisberger', '2019', 12.0, 351.0, 0.0, 0),
#  ('Ben Roethlisberger', '2020', 326.0, 3803.0, 33.0, 0),
#  ('Ben Roethlisberger', '2021', 258.0, 3740.0, 22.0, 1),
#  ('Blaine Gabbert', '2020', 18.0, 143.0, 2.0, 0),
#  ('Blaine Gabbert', '2021', 1.0, 67.0, 0.0, 0),
#  ('Blaine Gabbert', '2022', 7.0, 29.0, 1.0, 0),
#  ('Blaine Gabbert', '2023', 5.0, 185.0, 0.0, 0),
#  ('Blake Bortles', '2019', 0.0, 3.0, 0.0, 0),
#  ('Brandon Allen', '2019', 35.0, 515.0, 3.0, 0),
#  ('Brandon Allen', '2020', 56.0, 925.0, 5.0, 0),
#  ('Brandon Allen', '2021', 17.0, 149.0, 2.0, 0),
#  ('Brandon Allen', '2022', 0.0, 22.0, 0.0, 0),
#  ('Brett Hundley', '2019', 4.0, 49.0, 0.0, 0),
#  ('Brett Rypien', '2020', 15.0, 295.0, 2.0, 0),
#  ('Brett Rypien', '2021', 0.0, 0.0, 0.0, 0),
#  ('Brett Rypien', '2022', 20.0, 483.0, 2.0, 0),
#  ('Brett Rypien', '2023', 4.0, 172.0, 0.0, 0),
#  ('Brian Hoyer', '2019', 29.0, 372.0, 4.0, 0),
#  ('Brian Hoyer', '2020', 2.0, 130.0, 0.0, 0),
#  ('Brian Hoyer', '2021', 14.0, 227.0, 1.0, 0),
#  ('Brian Hoyer', '2022', 1.0, 37.0, 0.0, 0),
#  ('Brian Hoyer', '2023', 5.0, 231.0, 0.0, 0),
#  ('Brock Purdy', '2022', 128.0, 1374.0, 13.0, 1),
#  ('Brock Purdy', '2023', 347.0, 4280.0, 31.0, 2),
#  ('Bryce Perkins', '2022', 15.0, 161.0, 1.0, 0),
#  ('Bryce Young', '2023', 170.0, 2877.0, 11.0, 0),
#  ('C.J. Beathard', '2020', 64.0, 787.0, 6.0, 0),
#  ('C.J. Beathard', '2021', 1.0, 33.0, 0.0, 0),
#  ('C.J. Beathard', '2022', -1.0, 35.0, 0.0, 0),
#  ('C.J. Beathard', '2023', 20.0, 349.0, 1.0, 0),
#  ('C.J. Stroud', '2023', 314.0, 4108.0, 23.0, 3),
#  ('Cam Newton', '2019', 18.0, 572.0, 0.0, 0),
#  ('Cam Newton', '2020', 258.0, 2657.0, 8.0, 12),
#  ('Cam Newton', '2021', 90.0, 684.0, 4.0, 5),
#  ('Carson Wentz', '2019', 322.0, 4039.0, 27.0, 1),
#  ('Carson Wentz', '2020', 223.0, 2620.0, 16.0, 5),
#  ('Carson Wentz', '2021', 304.0, 3563.0, 27.0, 1),
#  ('Carson Wentz', '2022', 128.0, 1755.0, 11.0, 1),
#  ('Carson Wentz', '2023', 29.0, 163.0, 2.0, 1),
#  ('Case Keenum', '2019', 125.0, 1707.0, 11.0, 1),
#  ('Case Keenum', '2020', 1.0, 46.0, 0.0, 0),
#  ('Case Keenum', '2021', 33.0, 462.0, 3.0, 0),
#  ('Case Keenum', '2022', 0.0, 8.0, 0.0, 0),
#  ('Case Keenum', '2023', 11.0, 291.0, 1.0, 0),
#  ('Chad Henne', '2020', 26.0, 248.0, 2.0, 1),
#  ('Chad Henne', '2021', 3.0, 82.0, 0.0, 0),
#  ('Chad Henne', '2022', 0.0, 0.0, 0.0, 0),
#  ('Chase Daniel', '2019', 30.0, 435.0, 3.0, 0),
#  ('Chase Daniel', '2020', 12.0, 264.0, 1.0, 0),
#  ('Chase Daniel', '2021', 0.0, 0.0, 0.0, 0),
#  ('Chase Daniel', '2022', 10.0, 52.0, 1.0, 0),
#  ('Chris Streveler', '2020', 9.0, 105.0, 1.0, 0),
#  ('Chris Streveler', '2021', 1.0, 36.0, 0.0, 0),
#  ('Chris Streveler', '2022', 8.0, 90.0, 0.0, 0),
#  ('Clayton Tune', '2023', 7.0, 62.0, 0.0, 1),
#  ('Colt McCoy', '2019', 3.0, 122.0, 0.0, 0),
#  ('Colt McCoy', '2020', 18.0, 375.0, 1.0, 0),
#  ('Colt McCoy', '2021', 46.0, 740.0, 3.0, 0),
#  ('Colt McCoy', '2022', 31.0, 780.0, 1.0, 0),
#  ('Cooper Rush', '2021', 30.0, 422.0, 3.0, 0),
#  ('Cooper Rush', '2022', 63.0, 1051.0, 5.0, 0),
#  ('Cooper Rush', '2023', 1.0, 144.0, 0.0, 0),
#  ('Dak Prescott', '2019', 385.0, 4902.0, 30.0, 3),
#  ('Dak Prescott', '2020', 152.0, 1856.0, 9.0, 3),
#  ('Dak Prescott', '2021', 390.0, 4449.0, 37.0, 1),
#  ('Dak Prescott', '2022', 238.0, 2860.0, 23.0, 1),
#  ('Dak Prescott', '2023', 402.0, 4516.0, 36.0, 2),
#  ('Daniel Jones', '2019', 263.0, 3027.0, 24.0, 2),
#  ('Daniel Jones', '2020', 198.0, 2943.0, 11.0, 1),
#  ('Daniel Jones', '2021', 178.0, 2428.0, 10.0, 2),
#  ('Daniel Jones', '2022', 308.0, 3205.0, 15.0, 7),
#  ('Daniel Jones', '2023', 56.0, 909.0, 2.0, 1),
#  ('David Blough', '2019', 59.0, 984.0, 4.0, 0),
#  ('David Blough', '2020', 0.0, 49.0, 0.0, 0),
#  ('David Blough', '2021', 0.0, 0.0, 0.0, 0),
#  ('David Blough', '2022', 22.0, 402.0, 2.0, 0),
#  ('Davis Mills', '2021', 182.0, 2664.0, 16.0, 0),
#  ('Davis Mills', '2022', 208.0, 3118.0, 17.0, 2),
#  ('Davis Mills', '2023', 19.0, 173.0, 2.0, 0),
#  ('Davis Webb', '2021', 0.0, 0.0, 0.0, 0),
#  ('Davis Webb', '2022', 22.0, 168.0, 1.0, 1),
#  ('Derek Carr', '2019', 276.0, 4054.0, 21.0, 2),
#  ('Derek Carr', '2020', 324.0, 4103.0, 27.0, 3),
#  ('Derek Carr', '2021', 294.0, 4804.0, 23.0, 0),
#  ('Derek Carr', '2022', 258.0, 3522.0, 24.0, 0),
#  ('Derek Carr', '2023', 286.0, 3878.0, 25.0, 0),
#  ('Deshaun Watson', '2019', 364.0, 3852.0, 26.0, 7),
#  ('Deshaun Watson', '2020', 421.0, 4823.0, 33.0, 3),
#  ('Deshaun Watson', '2022', 96.0, 1102.0, 7.0, 1),
#  ('Deshaun Watson', '2023', 98.0, 1115.0, 7.0, 1),
#  ('Desmond Ridder', '2022', 38.0, 708.0, 2.0, 0),
#  ('Desmond Ridder', '2023', 197.0, 2836.0, 12.0, 5),
#  ('Devlin Hodges', '2019', 57.0, 1063.0, 5.0, 0),
#  ('Dorian Thompson-Robinson', '2023', 21.0, 440.0, 1.0, 0),
#  ('Drew Brees', '2019', 274.0, 2979.0, 27.0, 1),
#  ('Drew Brees', '2020', 255.0, 2942.0, 24.0, 2),
#  ('Drew Lock', '2019', 79.0, 1020.0, 7.0, 0),
#  ('Drew Lock', '2020', 204.0, 2933.0, 16.0, 3),
#  ('Drew Lock', '2021', 54.0, 787.0, 2.0, 2),
#  ('Drew Lock', '2023', 33.0, 543.0, 3.0, 0),
#  ('Dwayne Haskins', '2019', 85.0, 1365.0, 7.0, 0),
#  ('Dwayne Haskins', '2020', 76.0, 1439.0, 5.0, 1),
#  ('Easton Stick', '2020', 0.0, 4.0, 0.0, 0),
#  ('Easton Stick', '2023', 74.0, 1129.0, 3.0, 1),
#  ('Eli Manning', '2019', 66.0, 1042.0, 6.0, 0),
#  ('Gardner Minshew', '2019', 265.0, 3271.0, 21.0, 0),
#  ('Gardner Minshew', '2020', 188.0, 2259.0, 16.0, 1),
#  ('Gardner Minshew', '2021', 40.0, 439.0, 4.0, 0),
#  ('Gardner Minshew', '2022', 41.0, 663.0, 3.0, 1),
#  ('Gardner Minshew', '2023', 220.0, 3305.0, 15.0, 3),
#  ('Garrett Gilbert', '2019', 0.0, 0.0, 0.0, 0),
#  ('Garrett Gilbert', '2020', 15.0, 243.0, 1.0, 0),
#  ('Garrett Gilbert', '2021', 7.0, 194.0, 0.0, 0),
#  ('Geno Smith', '2020', 1.0, 33.0, 0.0, 0),
#  ('Geno Smith', '2021', 62.0, 702.0, 5.0, 1),
#  ('Geno Smith', '2022', 352.0, 4282.0, 30.0, 1),
#  ('Geno Smith', '2023', 262.0, 3624.0, 20.0, 1),
#  ('Ian Book', '2021', 1.0, 135.0, 0.0, 0),
#  ('Jacob Eason', '2021', -1.0, 25.0, 0.0, 0),
#  ('Jacob Eason', '2022', 0.0, 59.0, 0.0, 0),
#  ('Jacoby Brissett', '2019', 244.0, 2942.0, 18.0, 4),
#  ('Jacoby Brissett', '2020', 18.0, 17.0, 0.0, 3),
#  ('Jacoby Brissett', '2021', 78.0, 1283.0, 5.0, 1),
#  ('Jacoby Brissett', '2022', 187.0, 2608.0, 12.0, 2),
#  ('Jacoby Brissett', '2023', 27.0, 224.0, 3.0, 0),
#  ('Jake Browning', '2023', 163.0, 1936.0, 12.0, 3),
#  ('Jake Fromm', '2021', 13.0, 210.0, 1.0, 0),
#  ('Jake Luton', '2020', 31.0, 624.0, 2.0, 1),
#  ('Jalen Hurts', '2020', 113.0, 1061.0, 6.0, 3),
#  ('Jalen Hurts', '2021', 332.0, 3144.0, 16.0, 10),
#  ('Jalen Hurts', '2022', 412.0, 3701.0, 22.0, 13),
#  ('Jalen Hurts', '2023', 393.0, 3858.0, 23.0, 15),
#  ('Jameis Winston', '2019', 365.0, 5109.0, 33.0, 1),
#  ('Jameis Winston', '2020', 2.0, 75.0, 0.0, 0),
#  ('Jameis Winston', '2021', 141.0, 1170.0, 14.0, 1),
#  ('Jameis Winston', '2022', 49.0, 858.0, 4.0, 0),
#  ('Jameis Winston', '2023', 15.0, 264.0, 2.0, 0),
#  ('Jared Goff', '2019', 284.0, 4638.0, 22.0, 2),
#  ('Jared Goff', '2020', 275.0, 3952.0, 20.0, 4),
#  ('Jared Goff', '2021', 227.0, 3245.0, 19.0, 0),
#  ('Jared Goff', '2022', 334.0, 4438.0, 29.0, 0),
#  ('Jared Goff', '2023', 344.0, 4575.0, 30.0, 2),
#  ('Jaren Hall', '2023', 2.0, 168.0, 0.0, 0),
#  ('Jarrett Stidham', '2019', -2.0, 14.0, 0.0, 0),
#  ('Jarrett Stidham', '2020', 14.0, 256.0, 2.0, 0),
#  ('Jarrett Stidham', '2022', 49.0, 656.0, 4.0, 0),
#  ('Jarrett Stidham', '2023', 28.0, 496.0, 2.0, 0),
#  ('Jeff Driskel', '2019', 63.0, 685.0, 4.0, 1),
#  ('Jeff Driskel', '2020', 34.0, 432.0, 3.0, 0),
#  ('Jeff Driskel', '2022', 13.0, 108.0, 1.0, 0),
#  ('Jeff Driskel', '2023', 17.0, 166.0, 2.0, 0),
#  ('Jimmy Garoppolo', '2019', 294.0, 3978.0, 27.0, 1),
#  ('Jimmy Garoppolo', '2020', 74.0, 1096.0, 7.0, 0),
#  ('Jimmy Garoppolo', '2021', 260.0, 3810.0, 20.0, 3),
#  ('Jimmy Garoppolo', '2022', 192.0, 2437.0, 16.0, 2),
#  ('Jimmy Garoppolo', '2023', 74.0, 1205.0, 7.0, 0),
#  ('Joe Burrow', '2020', 196.0, 2688.0, 13.0, 3),
#  ('Joe Burrow', '2021', 372.0, 4611.0, 34.0, 2),
#  ('Joe Burrow', '2022', 411.0, 4475.0, 35.0, 5),
#  ('Joe Burrow', '2023', 170.0, 2309.0, 15.0, 0),
#  ('Joe Flacco', '2019', 94.0, 1822.0, 6.0, 0),
#  ('Joe Flacco', '2020', 64.0, 864.0, 6.0, 0),
#  ('Joe Flacco', '2021', 29.0, 338.0, 3.0, 0),
#  ('Joe Flacco', '2022', 60.0, 1051.0, 5.0, 0),
#  ('Joe Flacco', '2023', 125.0, 1616.0, 13.0, 0),
#  ('John Wolford', '2020', 12.0, 231.0, 0.0, 0),
#  ('John Wolford', '2021', -2.0, 5.0, 0.0, 0),
#  ('John Wolford', '2022', 16.0, 390.0, 1.0, 0),
#  ('Jordan Love', '2021', 23.0, 411.0, 2.0, 0),
#  ('Jordan Love', '2022', 12.0, 195.0, 1.0, 0),
#  ('Jordan Love', '2023', 373.0, 4159.0, 32.0, 4),
#  ('Josh Allen', '2019', 318.0, 3089.0, 20.0, 9),
#  ('Josh Allen', '2020', 461.0, 4544.0, 37.0, 8),
#  ('Josh Allen', '2021', 460.0, 4407.0, 36.0, 6),
#  ('Josh Allen', '2022', 455.0, 4283.0, 35.0, 7),
#  ('Josh Allen', '2023', 438.0, 4306.0, 29.0, 15),
#  ('Josh Johnson', '2021', 54.0, 638.0, 5.0, 0),
#  ('Josh Johnson', '2022', 0.0, 10.0, 0.0, 0),
#  ('Josh McCown', '2019', 0.0, 24.0, 0.0, 0),
#  ('Josh Rosen', '2019', 18.0, 567.0, 1.0, 0),
#  ('Josh Rosen', '2021', -4.0, 19.0, 0.0, 0),
#  ('Joshua Dobbs', '2020', 2.0, 2.0, 0.0, 0),
#  ('Joshua Dobbs', '2022', 26.0, 411.0, 2.0, 0),
#  ('Joshua Dobbs', '2023', 223.0, 2464.0, 13.0, 6),
#  ('Justin Fields', '2021', 135.0, 1870.0, 7.0, 2),
#  ('Justin Fields', '2022', 319.0, 2242.0, 17.0, 8),
#  ('Justin Fields', '2023', 250.0, 2562.0, 16.0, 4),
#  ('Justin Herbert', '2020', 384.0, 4336.0, 31.0, 5),
#  ('Justin Herbert', '2021', 442.0, 5014.0, 38.0, 3),
#  ('Justin Herbert', '2022', 320.0, 4739.0, 25.0, 0),
#  ('Justin Herbert', '2023', 265.0, 3134.0, 20.0, 3),
#  ('Kellen Mond', '2021', 0.0, 5.0, 0.0, 0),
#  ('Kenny Pickett', '2022', 152.0, 2404.0, 7.0, 3),
#  ('Kenny Pickett', '2023', 114.0, 2070.0, 6.0, 1),
#  ('Kirk Cousins', '2019', 288.0, 3603.0, 26.0, 1),
#  ('Kirk Cousins', '2020', 370.0, 4265.0, 35.0, 1),
#  ('Kirk Cousins', '2021', 357.0, 4221.0, 33.0, 1),
#  ('Kirk Cousins', '2022', 343.0, 4547.0, 29.0, 2),
#  ('Kirk Cousins', '2023', 184.0, 2331.0, 18.0, 0),
#  ('Kurt Benkert', '2021', 0.0, 0.0, 0.0, 0),
#  ('Kyle Allen', '2019', 211.0, 3322.0, 17.0, 2),
#  ('Kyle Allen', '2020', 50.0, 610.0, 4.0, 1),
#  ('Kyle Allen', '2021', 10.0, 120.0, 1.0, 0),
#  ('Kyle Allen', '2022', 20.0, 416.0, 2.0, 0),
#  ('Kyle Allen', '2023', 0.0, 0.0, 0.0, 0),
#  ('Kyle Trask', '2022', 0.0, 23.0, 0.0, 0),
#  ('Kyle Trask', '2023', 0.0, 0.0, 0.0, 0),
#  ('Kyler Murray', '2019', 311.0, 3722.0, 20.0, 4),
#  ('Kyler Murray', '2020', 418.0, 3971.0, 26.0, 11),
#  ('Kyler Murray', '2021', 335.0, 3787.0, 24.0, 5),
#  ('Kyler Murray', '2022', 222.0, 2368.0, 14.0, 3),
#  ('Kyler Murray', '2023', 160.0, 1799.0, 10.0, 3),
#  ('Lamar Jackson', '2019', 474.0, 3127.0, 36.0, 7),
#  ('Lamar Jackson', '2020', 375.0, 2757.0, 26.0, 7),
#  ('Lamar Jackson', '2021', 262.0, 2882.0, 16.0, 2),
#  ('Lamar Jackson', '2022', 258.0, 2242.0, 17.0, 3),
#  ('Lamar Jackson', '2023', 370.0, 3678.0, 24.0, 5),
#  ('Logan Woodside', '2020', 1.0, 7.0, 0.0, 0),
#  ('Logan Woodside', '2021', 0.0, 0.0, 0.0, 0),
#  ('Logan Woodside', '2023', -1.0, 27.0, 0.0, 0),
#  ('Luke Falk', '2019', 7.0, 416.0, 0.0, 0),
#  ('Mac Jones', '2021', 261.0, 3801.0, 22.0, 0),
#  ('Mac Jones', '2022', 188.0, 2997.0, 14.0, 1),
#  ('Mac Jones', '2023', 121.0, 2120.0, 10.0, 0),
#  ('Malik Willis', '2022', 16.0, 276.0, 0.0, 1),
#  ('Malik Willis', '2023', 2.0, 74.0, 0.0, 0),
#  ('Marcus Mariota', '2019', 94.0, 1203.0, 7.0, 0),
#  ('Marcus Mariota', '2020', 27.0, 226.0, 1.0, 1),
#  ('Marcus Mariota', '2021', 12.0, 4.0, 0.0, 1),
#  ('Marcus Mariota', '2022', 218.0, 2219.0, 15.0, 4),
#  ('Marcus Mariota', '2023', 12.0, 164.0, 1.0, 0),
#  ('Mason Rudolph', '2019', 128.0, 1765.0, 13.0, 0),
#  ('Mason Rudolph', '2020', 22.0, 324.0, 2.0, 0),
#  ('Mason Rudolph', '2021', 18.0, 277.0, 1.0, 0),
#  ('Mason Rudolph', '2023', 44.0, 719.0, 3.0, 0),
#  ('Matt Barkley', '2019', 7.0, 359.0, 0.0, 0),
#  ('Matt Barkley', '2020', 10.0, 197.0, 1.0, 0),
#  ('Matt Barkley', '2023', 0.0, 0.0, 0.0, 0),
#  ('Matt Moore', '2019', 49.0, 659.0, 4.0, 0),
#  ('Matt Ryan', '2019', 311.0, 4466.0, 26.0, 1),
#  ('Matt Ryan', '2020', 327.0, 4581.0, 26.0, 2),
#  ('Matt Ryan', '2021', 252.0, 3968.0, 20.0, 1),
#  ('Matt Ryan', '2022', 181.0, 3057.0, 14.0, 1),
#  ('Matt Schaub', '2019', 39.0, 580.0, 3.0, 0),
#  ('Matt Schaub', '2020', 0.0, 0.0, 0.0, 0),
#  ('Matthew Stafford', '2019', 201.0, 2499.0, 19.0, 0),
#  ('Matthew Stafford', '2020', 301.0, 4084.0, 26.0, 0),
#  ('Matthew Stafford', '2021', 405.0, 4886.0, 41.0, 0),
#  ('Matthew Stafford', '2022', 126.0, 2087.0, 10.0, 1),
#  ('Matthew Stafford', '2023', 281.0, 3965.0, 24.0, 0),
#  ('Mike Glennon', '2019', 6.0, 56.0, 1.0, 0),
#  ('Mike Glennon', '2020', 73.0, 1072.0, 7.0, 0),
#  ('Mike Glennon', '2021', 36.0, 790.0, 4.0, 1),
#  ('Mike White', '2021', 53.0, 953.0, 5.0, 0),
#  ('Mike White', '2022', 60.0, 1192.0, 3.0, 1),
#  ('Mike White', '2023', 5.0, 74.0, 1.0, 0),
#  ('Mitchell Trubisky', '2019', 228.0, 3138.0, 17.0, 2),
#  ('Mitchell Trubisky', '2020', 180.0, 2055.0, 16.0, 1),
#  ('Mitchell Trubisky', '2021', 6.0, 43.0, 0.0, 1),
#  ('Mitchell Trubisky', '2022', 75.0, 1252.0, 4.0, 2),
#  ('Mitchell Trubisky', '2023', 53.0, 632.0, 4.0, 2),
#  ('Nate Sudfeld', '2020', -1.0, 32.0, 0.0, 0),
#  ('Nate Sudfeld', '2022', 0.0, 0.0, 0.0, 0),
#  ('Nathan Peterman', '2020', 1.0, 25.0, 0.0, 0),
#  ('Nathan Peterman', '2021', 0.0, 0.0, 0.0, 0),
#  ('Nathan Peterman', '2022', 9.0, 139.0, 1.0, 0),
#  ('Nathan Peterman', '2023', 0.0, 0.0, 0.0, 0),
#  ('Nick Foles', '2019', 43.0, 736.0, 3.0, 0),
#  ('Nick Foles', '2020', 119.0, 1852.0, 10.0, 1),
#  ('Nick Foles', '2021', 18.0, 250.0, 1.0, 0),
#  ('Nick Foles', '2022', 0.0, 224.0, 0.0, 0),
#  ('Nick Mullens', '2019', 0.0, 0.0, 0.0, 0),
#  ('Nick Mullens', '2020', 138.0, 2437.0, 12.0, 0),
#  ('Nick Mullens', '2021', 11.0, 147.0, 1.0, 0),
#  ('Nick Mullens', '2022', 12.0, 224.0, 1.0, 0),
#  ('Nick Mullens', '2023', 77.0, 1306.0, 7.0, 0),
#  ('Patrick Mahomes', '2019', 329.0, 4031.0, 26.0, 2),
#  ('Patrick Mahomes', '2020', 439.0, 4740.0, 38.0, 2),
#  ('Patrick Mahomes', '2021', 428.0, 4839.0, 37.0, 2),
#  ('Patrick Mahomes', '2022', 482.0, 5250.0, 41.0, 4),
#  ('Patrick Mahomes', '2023', 324.0, 4183.0, 27.0, 0),
#  ('Philip Rivers', '2019', 276.0, 4615.0, 23.0, 0),
#  ('Philip Rivers', '2020', 281.0, 4169.0, 24.0, 0),
#  ('Phillip Walker', '2020', 9.0, 368.0, 1.0, 0),
#  ('Phillip Walker', '2021', 15.0, 362.0, 1.0, 0),
#  ('Phillip Walker', '2022', 42.0, 731.0, 3.0, 0),
#  ('Phillip Walker', '2023', 21.0, 674.0, 1.0, 0),
#  ('Robert Griffin III', '2019', 13.0, 225.0, 1.0, 0),
#  ('Robert Griffin III', '2020', 2.0, 42.0, 0.0, 0),
#  ('Russell Wilson', '2019', 379.0, 4110.0, 31.0, 3),
#  ('Russell Wilson', '2020', 428.0, 4212.0, 40.0, 2),
#  ('Russell Wilson', '2021', 281.0, 3113.0, 25.0, 2),
#  ('Russell Wilson', '2022', 242.0, 3524.0, 16.0, 3),
#  ('Russell Wilson', '2023', 301.0, 3070.0, 26.0, 3),
#  ('Ryan Finley', '2019', 28.0, 474.0, 2.0, 0),
#  ('Ryan Finley', '2020', 18.0, 164.0, 1.0, 1),
#  ('Ryan Fitzpatrick', '2019', 269.0, 3529.0, 20.0, 4),
#  ('Ryan Fitzpatrick', '2020', 172.0, 2091.0, 13.0, 2),
#  ('Ryan Fitzpatrick', '2021', 0.0, 13.0, 0.0, 0),
#  ('Ryan Griffin', '2019', 0.0, 18.0, 0.0, 0),
#  ('Ryan Tannehill', '2019', 261.0, 2742.0, 22.0, 4),
#  ('Ryan Tannehill', '2020', 395.0, 3819.0, 33.0, 7),
#  ('Ryan Tannehill', '2021', 295.0, 3734.0, 21.0, 7),
#  ('Ryan Tannehill', '2022', 179.0, 2536.0, 13.0, 2),
#  ('Ryan Tannehill', '2023', 82.0, 1616.0, 4.0, 1),
#  ('Sam Darnold', '2019', 221.0, 3024.0, 19.0, 2),
#  ('Sam Darnold', '2020', 144.0, 2208.0, 9.0, 2),
#  ('Sam Darnold', '2021', 170.0, 2527.0, 9.0, 5),
#  ('Sam Darnold', '2022', 98.0, 1143.0, 7.0, 2),
#  ('Sam Darnold', '2023', 26.0, 297.0, 2.0, 1),
#  ('Sam Ehlinger', '2021', 0.0, 0.0, 0.0, 0),
#  ('Sam Ehlinger', '2022', 40.0, 573.0, 3.0, 0),
#  ('Sam Howell', '2022', 19.0, 169.0, 1.0, 1),
#  ('Sam Howell', '2023', 289.0, 3946.0, 21.0, 5),
#  ('Sean Clifford', '2023', 1.0, 37.0, 0.0, 0),
#  ('Sean Mannion', '2019', 0.0, 126.0, 0.0, 0),
#  ('Sean Mannion', '2021', 14.0, 189.0, 1.0, 0),
#  ('Skylar Thompson', '2022', 17.0, 534.0, 1.0, 0),
#  ('Taylor Heinicke', '2020', 13.0, 137.0, 1.0, 0),
#  ('Taylor Heinicke', '2021', 249.0, 3419.0, 20.0, 1),
#  ('Taylor Heinicke', '2022', 138.0, 1859.0, 12.0, 1),
#  ('Taylor Heinicke', '2023', 73.0, 890.0, 5.0, 1),
#  ('Taysom Hill', '2019', 91.0, 55.0, 0.0, 1),
#  ('Taysom Hill', '2020', 156.0, 928.0, 4.0, 8),
#  ('Taysom Hill', '2023', 132.0, 83.0, 1.0, 4),
#  ('Teddy Bridgewater', '2019', 103.0, 1384.0, 9.0, 0),
#  ('Teddy Bridgewater', '2020', 262.0, 3733.0, 15.0, 5),
#  ('Teddy Bridgewater', '2021', 230.0, 3052.0, 18.0, 2),
#  ('Teddy Bridgewater', '2022', 44.0, 683.0, 4.0, 0),
#  ('Teddy Bridgewater', '2023', 0.0, 0.0, 0.0, 0),
#  ('Tim Boyle', '2019', 0.0, 15.0, 0.0, 0),
#  ('Tim Boyle', '2020', 0.0, 0.0, 0.0, 0),
#  ('Tim Boyle', '2021', 29.0, 526.0, 3.0, 0),
#  ('Tim Boyle', '2022', -3.0, 33.0, 0.0, 0),
#  ('Tim Boyle', '2023', 11.0, 360.0, 1.0, 0),
#  ('Tom Brady', '2019', 304.0, 4057.0, 24.0, 3),
#  ('Tom Brady', '2020', 408.0, 4633.0, 40.0, 3),
#  ('Tom Brady', '2021', 454.0, 5316.0, 43.0, 2),
#  ('Tom Brady', '2022', 319.0, 4694.0, 25.0, 1),
#  ('Tommy DeVito', '2023', 104.0, 1101.0, 8.0, 1),
#  ('Trace McSorley', '2019', 0.0, 0.0, 0.0, 0),
#  ('Trace McSorley', '2020', 10.0, 90.0, 1.0, 0),
#  ('Trace McSorley', '2022', 6.0, 412.0, 0.0, 0),
#  ('Trevor Lawrence', '2021', 212.0, 3641.0, 12.0, 2),
#  ('Trevor Lawrence', '2022', 341.0, 4113.0, 25.0, 5),
#  ('Trevor Lawrence', '2023', 299.0, 4016.0, 21.0, 4),
#  ('Trevor Siemian', '2019', 0.0, 3.0, 0.0, 0),
#  ('Trevor Siemian', '2021', 108.0, 1154.0, 11.0, 1),
#  ('Trevor Siemian', '2022', 11.0, 184.0, 1.0, 0),
#  ('Trevor Siemian', '2023', 29.0, 724.0, 2.0, 0),
#  ('Trey Lance', '2021', 71.0, 603.0, 5.0, 1),
#  ('Trey Lance', '2022', 11.0, 194.0, 0.0, 0),
#  ('Tua Tagovailoa', '2020', 149.0, 1814.0, 11.0, 3),
#  ('Tua Tagovailoa', '2021', 204.0, 2653.0, 16.0, 3),
#  ('Tua Tagovailoa', '2022', 272.0, 3548.0, 25.0, 0),
#  ('Tua Tagovailoa', '2023', 318.0, 4624.0, 29.0, 0),
#  ('Tyler Bray', '2020', 0.0, 18.0, 0.0, 0),
#  ('Tyler Huntley', '2020', 1.0, 15.0, 0.0, 0),
#  ('Tyler Huntley', '2021', 86.0, 1081.0, 3.0, 2),
#  ('Tyler Huntley', '2022', 50.0, 658.0, 2.0, 1),
#  ('Tyler Huntley', '2023', 28.0, 203.0, 3.0, 0),
#  ('Tyrod Taylor', '2019', 8.0, 33.0, 1.0, 0),
#  ('Tyrod Taylor', '2020', 8.0, 208.0, 0.0, 0),
#  ('Tyrod Taylor', '2021', 87.0, 966.0, 5.0, 3),
#  ('Tyrod Taylor', '2022', 13.0, 58.0, 1.0, 0),
#  ('Tyrod Taylor', '2023', 91.0, 1341.0, 5.0, 0),
#  ('Tyson Bagent', '2023', 58.0, 859.0, 3.0, 2),
#  ('Will Grier', '2019', 0.0, 228.0, 0.0, 0),
#  ('Will Levis', '2023', 115.0, 1808.0, 8.0, 1),
#  ('Zach Wilson', '2021', 163.0, 2334.0, 9.0, 4),
#  ('Zach Wilson', '2022', 105.0, 1688.0, 6.0, 1),
#  ('Zach Wilson', '2023', 132.0, 2271.0, 8.0, 0)]

# %%
data_dict = {}

# Iterate over the list of tuples
for name, year, fantasy_points, Passing_yards,Passing_TDs, Rush_TDs in results:
    # If the name is not already a key in the dictionary, add it with an empty dictionary as its value
    if name not in data_dict:
        data_dict[name] = {}
    
    # Add or update the number as key and its corresponding value
    data_dict[name][year] = {
        'Fantasy_Points': fantasy_points,
        'PassingYard_Points': Passing_yards * .04,
        'Passing_TD_Points': Passing_TDs * 4,
        'Rush_TD_Points': Rush_TDs * 6
    }# Replace `value` with the actual value you want to associate with the number

# Print the resulting dictionary
print(data_dict)
# Out:
# {'A.J. McCarron': {'2019': {'Fantasy_Points': 16.0, 'PassingYard_Points': 9.0, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 6}, '2020': {'Fantasy_Points': 0.0, 'PassingYard_Points': 0.8, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 0}, '2023': {'Fantasy_Points': 0.0, 'PassingYard_Points': 0.76, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 0}}, 'Aaron Rodgers': {'2019': {'Fantasy_Points': 322.0, 'PassingYard_Points': 160.08, 'Passing_TD_Points': 104.0, 'Rush_TD_Points': 6}, '2020': {'Fantasy_Points': 469.0, 'PassingYard_Points': 171.96, 'Passing_TD_Points': 192.0, 'Rush_TD_Points': 18}, '2021': {'Fantasy_Points': 394.0, 'PassingYard_Points': 164.6, 'Passing_TD_Points': 148.0, 'Rush_TD_Points': 18}, '2022': {'Fantasy_Points': 286.0, 'PassingYard_Points': 147.8, 'Passing_TD_Points': 104.0, 'Rush_TD_Points': 6}, '2023': {'Fantasy_Points': 0.0, 'PassingYard_Points': 0.0, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 0}}, "Aidan O'Connell": {'2023': {'Fantasy_Points': 144.0, 'PassingYard_Points': 88.72, 'Passing_TD_Points': 48.0, 'Rush_TD_Points': 6}}, 'Alex Smith': {'2020': {'Fantasy_Points': 79.0, 'PassingYard_Points': 63.28, 'Passing_TD_Points': 24.0, 'Rush_TD_Points': 0}}, 'Alex Tanney': {'2019': {'Fantasy_Points': 0.0, 'PassingYard_Points': 0.04, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 0}}, 'Andy Dalton': {'2019': {'Fantasy_Points': 232.0, 'PassingYard_Points': 139.76, 'Passing_TD_Points': 64.0, 'Rush_TD_Points': 24}, '2020': {'Fantasy_Points': 158.0, 'PassingYard_Points': 86.8, 'Passing_TD_Points': 56.0, 'Rush_TD_Points': 0}, '2021': {'Fantasy_Points': 96.0, 'PassingYard_Points': 60.6, 'Passing_TD_Points': 32.0, 'Rush_TD_Points': 0}, '2022': {'Fantasy_Points': 204.0, 'PassingYard_Points': 114.84, 'Passing_TD_Points': 72.0, 'Rush_TD_Points': 0}, '2023': {'Fantasy_Points': 27.0, 'PassingYard_Points': 14.44, 'Passing_TD_Points': 8.0, 'Rush_TD_Points': 0}}, 'Anthony Brown': {'2022': {'Fantasy_Points': 6.0, 'PassingYard_Points': 12.08, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 0}}, 'Anthony Richardson': {'2023': {'Fantasy_Points': 76.0, 'PassingYard_Points': 23.080000000000002, 'Passing_TD_Points': 12.0, 'Rush_TD_Points': 24}}, 'Bailey Zappe': {'2022': {'Fantasy_Points': 51.0, 'PassingYard_Points': 31.240000000000002, 'Passing_TD_Points': 20.0, 'Rush_TD_Points': 0}, '2023': {'Fantasy_Points': 76.0, 'PassingYard_Points': 50.88, 'Passing_TD_Points': 24.0, 'Rush_TD_Points': 6}}, 'Baker Mayfield': {'2019': {'Fantasy_Points': 262.0, 'PassingYard_Points': 153.08, 'Passing_TD_Points': 88.0, 'Rush_TD_Points': 18}, '2020': {'Fantasy_Points': 288.0, 'PassingYard_Points': 142.52, 'Passing_TD_Points': 104.0, 'Rush_TD_Points': 6}, '2021': {'Fantasy_Points': 205.0, 'PassingYard_Points': 120.4, 'Passing_TD_Points': 68.0, 'Rush_TD_Points': 6}, '2022': {'Fantasy_Points': 134.0, 'PassingYard_Points': 86.52, 'Passing_TD_Points': 40.0, 'Rush_TD_Points': 6}, '2023': {'Fantasy_Points': 319.0, 'PassingYard_Points': 161.76, 'Passing_TD_Points': 112.0, 'Rush_TD_Points': 6}}, 'Ben DiNucci': {'2020': {'Fantasy_Points': 8.0, 'PassingYard_Points': 8.76, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 0}}, 'Ben Roethlisberger': {'2019': {'Fantasy_Points': 12.0, 'PassingYard_Points': 14.040000000000001, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 0}, '2020': {'Fantasy_Points': 326.0, 'PassingYard_Points': 152.12, 'Passing_TD_Points': 132.0, 'Rush_TD_Points': 0}, '2021': {'Fantasy_Points': 258.0, 'PassingYard_Points': 149.6, 'Passing_TD_Points': 88.0, 'Rush_TD_Points': 6}}, 'Blaine Gabbert': {'2020': {'Fantasy_Points': 18.0, 'PassingYard_Points': 5.72, 'Passing_TD_Points': 8.0, 'Rush_TD_Points': 0}, '2021': {'Fantasy_Points': 1.0, 'PassingYard_Points': 2.68, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 0}, '2022': {'Fantasy_Points': 7.0, 'PassingYard_Points': 1.16, 'Passing_TD_Points': 4.0, 'Rush_TD_Points': 0}, '2023': {'Fantasy_Points': 5.0, 'PassingYard_Points': 7.4, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 0}}, 'Blake Bortles': {'2019': {'Fantasy_Points': 0.0, ...

# %%
name_values_dict = {}
years = ['2019','2020','2021','2022','2023']

# Iterate over the data dictionaries
for name, nested_dict in data_dict.items():
    # Extract values and add them to the list
    values_list = [nested_dict.get(year, {'Fantasy_Points': 0, 'PassingYard_Points' : 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}) for year in years]
    # Add the list of values to the dictionary
    name_values_dict[name] = values_list

# Print the resulting dictionary
print(name_values_dict)
# Out:
# {'A.J. McCarron': [{'Fantasy_Points': 16.0, 'PassingYard_Points': 9.0, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 6}, {'Fantasy_Points': 0.0, 'PassingYard_Points': 0.8, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0.0, 'PassingYard_Points': 0.76, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 0}], 'Aaron Rodgers': [{'Fantasy_Points': 322.0, 'PassingYard_Points': 160.08, 'Passing_TD_Points': 104.0, 'Rush_TD_Points': 6}, {'Fantasy_Points': 469.0, 'PassingYard_Points': 171.96, 'Passing_TD_Points': 192.0, 'Rush_TD_Points': 18}, {'Fantasy_Points': 394.0, 'PassingYard_Points': 164.6, 'Passing_TD_Points': 148.0, 'Rush_TD_Points': 18}, {'Fantasy_Points': 286.0, 'PassingYard_Points': 147.8, 'Passing_TD_Points': 104.0, 'Rush_TD_Points': 6}, {'Fantasy_Points': 0.0, 'PassingYard_Points': 0.0, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 0}], "Aidan O'Connell": [{'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 144.0, 'PassingYard_Points': 88.72, 'Passing_TD_Points': 48.0, 'Rush_TD_Points': 6}], 'Alex Smith': [{'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 79.0, 'PassingYard_Points': 63.28, 'Passing_TD_Points': 24.0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}], 'Alex Tanney': [{'Fantasy_Points': 0.0, 'PassingYard_Points': 0.04, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}], 'Andy Dalton': [{'Fantasy_Points': 232.0, 'PassingYard_Points': 139.76, 'Passing_TD_Points': 64.0, 'Rush_TD_Points': 24}, {'Fantasy_Points': 158.0, 'PassingYard_Points': 86.8, 'Passing_TD_Points': 56.0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 96.0, 'PassingYard_Points': 60.6, 'Passing_TD_Points': 32.0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 204.0, 'PassingYard_Points': 114.84, 'Passing_TD_Points': 72.0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 27.0, 'PassingYard_Points': 14.44, 'Passing_TD_Points': 8.0, 'Rush_TD_Points': 0}], 'Anthony Brown': [{'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 6.0, 'PassingYard_Points': 12.08, 'Passing_TD_Points': 0.0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}], 'Anthony Richardson': [{'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 0, 'PassingYard_Points': 0, 'Passing_TD_Points': 0, 'Rush_TD_Points': 0}, {'Fantasy_Points': 76.0, 'PassingYard_Points': 23.0800 ...

# %%
name_values_dict
# Out:
# {'A.J. McCarron': [{'Fantasy_Points': 16.0,
#    'PassingYard_Points': 9.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.8,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.76,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0}],
#  'Aaron Rodgers': [{'Fantasy_Points': 322.0,
#    'PassingYard_Points': 160.08,
#    'Passing_TD_Points': 104.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 469.0,
#    'PassingYard_Points': 171.96,
#    'Passing_TD_Points': 192.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 394.0,
#    'PassingYard_Points': 164.6,
#    'Passing_TD_Points': 148.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 286.0,
#    'PassingYard_Points': 147.8,
#    'Passing_TD_Points': 104.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0}],
#  "Aidan O'Connell": [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 144.0,
#    'PassingYard_Points': 88.72,
#    'Passing_TD_Points': 48.0,
#    'Rush_TD_Points': 6}],
#  'Alex Smith': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 79.0,
#    'PassingYard_Points': 63.28,
#    'Passing_TD_Points': 24.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Alex Tanney': [{'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.04,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Andy Dalton': [{'Fantasy_Points': 232.0,
#    'PassingYard_Points': 139.76,
#    'Passing_TD_Points': 64.0,
#    'Rush_TD_Points': 24},
#   {'Fantasy_Points': 158.0,
#    'PassingYard_Points': 86.8,
#    'Passing_TD_Points': 56.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 96.0,
#    'PassingYard_Points': 60.6,
#    'Passing_TD_Points': 32.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 204.0,
#    'PassingYard_Points': 114.84,
#    'Passing_TD_Points': 72.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 27.0,
#    'PassingYard_Points': 14.44,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0}],
#  'Anthony Brown': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 6.0,
#    'PassingYard_Points': 12.08,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Anthony Richardson': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 76.0,
#    'PassingYard_Points': 23.080000000000002,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 24}],
#  'Bailey Zappe': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 51.0,
#    'PassingYard_Points': 31.240000000000002,
#    'Passing_TD_Points': 20.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 76.0,
#    'PassingYard_Points': 50.88,
#    'Passing_TD_Points': 24.0,
#    'Rush_TD_Points': 6}],
#  'Baker Mayfield': [{'Fantasy_Points': 262.0,
#    'PassingYard_Points': 153.08,
#    'Passing_TD_Points': 88.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 288.0,
#    'PassingYard_Points': 142.52,
#    'Passing_TD_Points': 104.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 205.0,
#    'PassingYard_Points': 120.4,
#    'Passing_TD_Points': 68.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 134.0,
#    'PassingYard_Points': 86.52,
#    'Passing_TD_Points': 40.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 319.0,
#    'PassingYard_Points': 161.76,
#    'Passing_TD_Points': 112.0,
#    'Rush_TD_Points': 6}],
#  'Ben DiNucci': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 8.0,
#    'PassingYard_Points': 8.76,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Ben Roethlisberger': [{'Fantasy_Points': 12.0,
#    'PassingYard_Points': 14.040000000000001,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 326.0,
#    'PassingYard_Points': 152.12,
#    'Passing_TD_Points': 132.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 258.0,
#    'PassingYard_Points': 149.6,
#    'Passing_TD_Points': 88.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Blaine Gabbert': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 18.0,
#    'PassingYard_Points': 5.72,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 1.0,
#    'PassingYard_Points': 2.68,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 7.0,
#    'PassingYard_Points': 1.16,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 5.0,
#    'PassingYard_Points': 7.4,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0}],
#  'Blake Bortles': [{'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.12,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Brandon Allen': [{'Fantasy_Points': 35.0,
#    'PassingYard_Points': 20.6,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 56.0,
#    'PassingYard_Points': 37.0,
#    'Passing_TD_Points': 20.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 17.0,
#    'PassingYard_Points': 5.96,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.88,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Brett Hundley': [{'Fantasy_Points': 4.0,
#    'PassingYard_Points': 1.96,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Brett Rypien': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 15.0,
#    'PassingYard_Points': 11.8,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 20.0,
#    'PassingYard_Points': 19.32,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 4.0,
#    'PassingYard_Points': 6.88,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0}],
#  'Brian Hoyer': [{'Fantasy_Points': 29.0,
#    'PassingYard_Points': 14.88,
#    'Passing_TD_Points': 16.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 2.0,
#    'PassingYard_Points': 5.2,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 14.0,
#    'PassingYard_Points': 9.08,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 1.0,
#    'PassingYard_Points': 1.48,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 5.0,
#    'PassingYard_Points': 9.24,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0}],
#  'Brock Purdy': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 128.0,
#    'PassingYard_Points': 54.96,
#    'Passing_TD_Points': 52.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 347.0,
#    'PassingYard_Points': 171.20000000000002,
#    'Passing_TD_Points': 124.0,
#    'Rush_TD_Points': 12}],
#  'Bryce Perkins': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 15.0,
#    'PassingYard_Points': 6.44,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Bryce Young': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 170.0,
#    'PassingYard_Points': 115.08,
#    'Passing_TD_Points': 44.0,
#    'Rush_TD_Points': 0}],
#  'C.J. Beathard': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 64.0,
#    'PassingYard_Points': 31.48,
#    'Passing_TD_Points': 24.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 1.0,
#    'PassingYard_Points': 1.32,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': -1.0,
#    'PassingYard_Points': 1.4000000000000001,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 20.0,
#    'PassingYard_Points': 13.96,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0}],
#  'C.J. Stroud': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 314.0,
#    'PassingYard_Points': 164.32,
#    'Passing_TD_Points': 92.0,
#    'Rush_TD_Points': 18}],
#  'Cam Newton': [{'Fantasy_Points': 18.0,
#    'PassingYard_Points': 22.88,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 258.0,
#    'PassingYard_Points': 106.28,
#    'Passing_TD_Points': 32.0,
#    'Rush_TD_Points': 72},
#   {'Fantasy_Points': 90.0,
#    'PassingYard_Points': 27.36,
#    'Passing_TD_Points': 16.0,
#    'Rush_TD_Points': 30},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Carson Wentz': [{'Fantasy_Points': 322.0,
#    'PassingYard_Points': 161.56,
#    'Passing_TD_Points': 108.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 223.0,
#    'PassingYard_Points': 104.8,
#    'Passing_TD_Points': 64.0,
#    'Rush_TD_Points': 30},
#   {'Fantasy_Points': 304.0,
#    'PassingYard_Points': 142.52,
#    'Passing_TD_Points': 108.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 128.0,
#    'PassingYard_Points': 70.2,
#    'Passing_TD_Points': 44.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 29.0,
#    'PassingYard_Points': 6.5200000000000005,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 6}],
#  'Case Keenum': [{'Fantasy_Points': 125.0,
#    'PassingYard_Points': 68.28,
#    'Passing_TD_Points': 44.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 1.0,
#    'PassingYard_Points': 1.84,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 33.0,
#    'PassingYard_Points': 18.48,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.32,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 11.0,
#    'PassingYard_Points': 11.64,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0}],
#  'Chad Henne': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 26.0,
#    'PassingYard_Points': 9.92,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 3.0,
#    'PassingYard_Points': 3.2800000000000002,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Chase Daniel': [{'Fantasy_Points': 30.0,
#    'PassingYard_Points': 17.400000000000002,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 12.0,
#    'PassingYard_Points': 10.56,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 10.0,
#    'PassingYard_Points': 2.08,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Chris Streveler': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 9.0,
#    'PassingYard_Points': 4.2,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 1.0,
#    'PassingYard_Points': 1.44,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 8.0,
#    'PassingYard_Points': 3.6,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Clayton Tune': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 7.0,
#    'PassingYard_Points': 2.48,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 6}],
#  'Colt McCoy': [{'Fantasy_Points': 3.0,
#    'PassingYard_Points': 4.88,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 18.0,
#    'PassingYard_Points': 15.0,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 46.0,
#    'PassingYard_Points': 29.6,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 31.0,
#    'PassingYard_Points': 31.2,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Cooper Rush': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 30.0,
#    'PassingYard_Points': 16.88,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 63.0,
#    'PassingYard_Points': 42.04,
#    'Passing_TD_Points': 20.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 1.0,
#    'PassingYard_Points': 5.76,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0}],
#  'Dak Prescott': [{'Fantasy_Points': 385.0,
#    'PassingYard_Points': 196.08,
#    'Passing_TD_Points': 120.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 152.0,
#    'PassingYard_Points': 74.24,
#    'Passing_TD_Points': 36.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 390.0,
#    'PassingYard_Points': 177.96,
#    'Passing_TD_Points': 148.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 238.0,
#    'PassingYard_Points': 114.4,
#    'Passing_TD_Points': 92.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 402.0,
#    'PassingYard_Points': 180.64000000000001,
#    'Passing_TD_Points': 144.0,
#    'Rush_TD_Points': 12}],
#  'Daniel Jones': [{'Fantasy_Points': 263.0,
#    'PassingYard_Points': 121.08,
#    'Passing_TD_Points': 96.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 198.0,
#    'PassingYard_Points': 117.72,
#    'Passing_TD_Points': 44.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 178.0,
#    'PassingYard_Points': 97.12,
#    'Passing_TD_Points': 40.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 308.0,
#    'PassingYard_Points': 128.2,
#    'Passing_TD_Points': 60.0,
#    'Rush_TD_Points': 42},
#   {'Fantasy_Points': 56.0,
#    'PassingYard_Points': 36.36,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 6}],
#  'David Blough': [{'Fantasy_Points': 59.0,
#    'PassingYard_Points': 39.36,
#    'Passing_TD_Points': 16.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 1.96,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 22.0,
#    'PassingYard_Points': 16.080000000000002,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Davis Mills': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 182.0,
#    'PassingYard_Points': 106.56,
#    'Passing_TD_Points': 64.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 208.0,
#    'PassingYard_Points': 124.72,
#    'Passing_TD_Points': 68.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 19.0,
#    'PassingYard_Points': 6.92,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0}],
#  'Davis Webb': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 22.0,
#    'PassingYard_Points': 6.72,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Derek Carr': [{'Fantasy_Points': 276.0,
#    'PassingYard_Points': 162.16,
#    'Passing_TD_Points': 84.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 324.0,
#    'PassingYard_Points': 164.12,
#    'Passing_TD_Points': 108.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 294.0,
#    'PassingYard_Points': 192.16,
#    'Passing_TD_Points': 92.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 258.0,
#    'PassingYard_Points': 140.88,
#    'Passing_TD_Points': 96.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 286.0,
#    'PassingYard_Points': 155.12,
#    'Passing_TD_Points': 100.0,
#    'Rush_TD_Points': 0}],
#  'Deshaun Watson': [{'Fantasy_Points': 364.0,
#    'PassingYard_Points': 154.08,
#    'Passing_TD_Points': 104.0,
#    'Rush_TD_Points': 42},
#   {'Fantasy_Points': 421.0,
#    'PassingYard_Points': 192.92000000000002,
#    'Passing_TD_Points': 132.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 96.0,
#    'PassingYard_Points': 44.08,
#    'Passing_TD_Points': 28.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 98.0,
#    'PassingYard_Points': 44.6,
#    'Passing_TD_Points': 28.0,
#    'Rush_TD_Points': 6}],
#  'Desmond Ridder': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 38.0,
#    'PassingYard_Points': 28.32,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 197.0,
#    'PassingYard_Points': 113.44,
#    'Passing_TD_Points': 48.0,
#    'Rush_TD_Points': 30}],
#  'Devlin Hodges': [{'Fantasy_Points': 57.0,
#    'PassingYard_Points': 42.52,
#    'Passing_TD_Points': 20.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Dorian Thompson-Robinson': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 21.0,
#    'PassingYard_Points': 17.6,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0}],
#  'Drew Brees': [{'Fantasy_Points': 274.0,
#    'PassingYard_Points': 119.16,
#    'Passing_TD_Points': 108.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 255.0,
#    'PassingYard_Points': 117.68,
#    'Passing_TD_Points': 96.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Drew Lock': [{'Fantasy_Points': 79.0,
#    'PassingYard_Points': 40.800000000000004,
#    'Passing_TD_Points': 28.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 204.0,
#    'PassingYard_Points': 117.32000000000001,
#    'Passing_TD_Points': 64.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 54.0,
#    'PassingYard_Points': 31.48,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 33.0,
#    'PassingYard_Points': 21.72,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 0}],
#  'Dwayne Haskins': [{'Fantasy_Points': 85.0,
#    'PassingYard_Points': 54.6,
#    'Passing_TD_Points': 28.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 76.0,
#    'PassingYard_Points': 57.56,
#    'Passing_TD_Points': 20.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Easton Stick': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.16,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 74.0,
#    'PassingYard_Points': 45.160000000000004,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 6}],
#  'Eli Manning': [{'Fantasy_Points': 66.0,
#    'PassingYard_Points': 41.68,
#    'Passing_TD_Points': 24.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Gardner Minshew': [{'Fantasy_Points': 265.0,
#    'PassingYard_Points': 130.84,
#    'Passing_TD_Points': 84.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 188.0,
#    'PassingYard_Points': 90.36,
#    'Passing_TD_Points': 64.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 40.0,
#    'PassingYard_Points': 17.56,
#    'Passing_TD_Points': 16.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 41.0,
#    'PassingYard_Points': 26.52,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 220.0,
#    'PassingYard_Points': 132.2,
#    'Passing_TD_Points': 60.0,
#    'Rush_TD_Points': 18}],
#  'Garrett Gilbert': [{'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 15.0,
#    'PassingYard_Points': 9.72,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 7.0,
#    'PassingYard_Points': 7.76,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Geno Smith': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 1.0,
#    'PassingYard_Points': 1.32,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 62.0,
#    'PassingYard_Points': 28.080000000000002,
#    'Passing_TD_Points': 20.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 352.0,
#    'PassingYard_Points': 171.28,
#    'Passing_TD_Points': 120.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 262.0,
#    'PassingYard_Points': 144.96,
#    'Passing_TD_Points': 80.0,
#    'Rush_TD_Points': 6}],
#  'Ian Book': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 1.0,
#    'PassingYard_Points': 5.4,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Jacob Eason': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': -1.0,
#    'PassingYard_Points': 1.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 2.36,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Jacoby Brissett': [{'Fantasy_Points': 244.0,
#    'PassingYard_Points': 117.68,
#    'Passing_TD_Points': 72.0,
#    'Rush_TD_Points': 24},
#   {'Fantasy_Points': 18.0,
#    'PassingYard_Points': 0.68,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 78.0,
#    'PassingYard_Points': 51.32,
#    'Passing_TD_Points': 20.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 187.0,
#    'PassingYard_Points': 104.32000000000001,
#    'Passing_TD_Points': 48.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 27.0,
#    'PassingYard_Points': 8.96,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 0}],
#  'Jake Browning': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 163.0,
#    'PassingYard_Points': 77.44,
#    'Passing_TD_Points': 48.0,
#    'Rush_TD_Points': 18}],
#  'Jake Fromm': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 13.0,
#    'PassingYard_Points': 8.4,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Jake Luton': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 31.0,
#    'PassingYard_Points': 24.96,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Jalen Hurts': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 113.0,
#    'PassingYard_Points': 42.44,
#    'Passing_TD_Points': 24.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 332.0,
#    'PassingYard_Points': 125.76,
#    'Passing_TD_Points': 64.0,
#    'Rush_TD_Points': 60},
#   {'Fantasy_Points': 412.0,
#    'PassingYard_Points': 148.04,
#    'Passing_TD_Points': 88.0,
#    'Rush_TD_Points': 78},
#   {'Fantasy_Points': 393.0,
#    'PassingYard_Points': 154.32,
#    'Passing_TD_Points': 92.0,
#    'Rush_TD_Points': 90}],
#  'Jameis Winston': [{'Fantasy_Points': 365.0,
#    'PassingYard_Points': 204.36,
#    'Passing_TD_Points': 132.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 2.0,
#    'PassingYard_Points': 3.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 141.0,
#    'PassingYard_Points': 46.800000000000004,
#    'Passing_TD_Points': 56.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 49.0,
#    'PassingYard_Points': 34.32,
#    'Passing_TD_Points': 16.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 15.0,
#    'PassingYard_Points': 10.56,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0}],
#  'Jared Goff': [{'Fantasy_Points': 284.0,
#    'PassingYard_Points': 185.52,
#    'Passing_TD_Points': 88.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 275.0,
#    'PassingYard_Points': 158.08,
#    'Passing_TD_Points': 80.0,
#    'Rush_TD_Points': 24},
#   {'Fantasy_Points': 227.0,
#    'PassingYard_Points': 129.8,
#    'Passing_TD_Points': 76.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 334.0,
#    'PassingYard_Points': 177.52,
#    'Passing_TD_Points': 116.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 344.0,
#    'PassingYard_Points': 183.0,
#    'Passing_TD_Points': 120.0,
#    'Rush_TD_Points': 12}],
#  'Jaren Hall': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 2.0,
#    'PassingYard_Points': 6.72,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0}],
#  'Jarrett Stidham': [{'Fantasy_Points': -2.0,
#    'PassingYard_Points': 0.56,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 14.0,
#    'PassingYard_Points': 10.24,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 49.0,
#    'PassingYard_Points': 26.240000000000002,
#    'Passing_TD_Points': 16.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 28.0,
#    'PassingYard_Points': 19.84,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0}],
#  'Jeff Driskel': [{'Fantasy_Points': 63.0,
#    'PassingYard_Points': 27.400000000000002,
#    'Passing_TD_Points': 16.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 34.0,
#    'PassingYard_Points': 17.28,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 13.0,
#    'PassingYard_Points': 4.32,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 17.0,
#    'PassingYard_Points': 6.640000000000001,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0}],
#  'Jimmy Garoppolo': [{'Fantasy_Points': 294.0,
#    'PassingYard_Points': 159.12,
#    'Passing_TD_Points': 108.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 74.0,
#    'PassingYard_Points': 43.84,
#    'Passing_TD_Points': 28.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 260.0,
#    'PassingYard_Points': 152.4,
#    'Passing_TD_Points': 80.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 192.0,
#    'PassingYard_Points': 97.48,
#    'Passing_TD_Points': 64.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 74.0,
#    'PassingYard_Points': 48.2,
#    'Passing_TD_Points': 28.0,
#    'Rush_TD_Points': 0}],
#  'Joe Burrow': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 196.0,
#    'PassingYard_Points': 107.52,
#    'Passing_TD_Points': 52.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 372.0,
#    'PassingYard_Points': 184.44,
#    'Passing_TD_Points': 136.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 411.0,
#    'PassingYard_Points': 179.0,
#    'Passing_TD_Points': 140.0,
#    'Rush_TD_Points': 30},
#   {'Fantasy_Points': 170.0,
#    'PassingYard_Points': 92.36,
#    'Passing_TD_Points': 60.0,
#    'Rush_TD_Points': 0}],
#  'Joe Flacco': [{'Fantasy_Points': 94.0,
#    'PassingYard_Points': 72.88,
#    'Passing_TD_Points': 24.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 64.0,
#    'PassingYard_Points': 34.56,
#    'Passing_TD_Points': 24.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 29.0,
#    'PassingYard_Points': 13.52,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 60.0,
#    'PassingYard_Points': 42.04,
#    'Passing_TD_Points': 20.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 125.0,
#    'PassingYard_Points': 64.64,
#    'Passing_TD_Points': 52.0,
#    'Rush_TD_Points': 0}],
#  'John Wolford': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 12.0,
#    'PassingYard_Points': 9.24,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': -2.0,
#    'PassingYard_Points': 0.2,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 16.0,
#    'PassingYard_Points': 15.6,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Jordan Love': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 23.0,
#    'PassingYard_Points': 16.44,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 12.0,
#    'PassingYard_Points': 7.8,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 373.0,
#    'PassingYard_Points': 166.36,
#    'Passing_TD_Points': 128.0,
#    'Rush_TD_Points': 24}],
#  'Josh Allen': [{'Fantasy_Points': 318.0,
#    'PassingYard_Points': 123.56,
#    'Passing_TD_Points': 80.0,
#    'Rush_TD_Points': 54},
#   {'Fantasy_Points': 461.0,
#    'PassingYard_Points': 181.76,
#    'Passing_TD_Points': 148.0,
#    'Rush_TD_Points': 48},
#   {'Fantasy_Points': 460.0,
#    'PassingYard_Points': 176.28,
#    'Passing_TD_Points': 144.0,
#    'Rush_TD_Points': 36},
#   {'Fantasy_Points': 455.0,
#    'PassingYard_Points': 171.32,
#    'Passing_TD_Points': 140.0,
#    'Rush_TD_Points': 42},
#   {'Fantasy_Points': 438.0,
#    'PassingYard_Points': 172.24,
#    'Passing_TD_Points': 116.0,
#    'Rush_TD_Points': 90}],
#  'Josh Johnson': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 54.0,
#    'PassingYard_Points': 25.52,
#    'Passing_TD_Points': 20.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.4,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Josh McCown': [{'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.96,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Josh Rosen': [{'Fantasy_Points': 18.0,
#    'PassingYard_Points': 22.68,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': -4.0,
#    'PassingYard_Points': 0.76,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Joshua Dobbs': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 2.0,
#    'PassingYard_Points': 0.08,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 26.0,
#    'PassingYard_Points': 16.44,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 223.0,
#    'PassingYard_Points': 98.56,
#    'Passing_TD_Points': 52.0,
#    'Rush_TD_Points': 36}],
#  'Justin Fields': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 135.0,
#    'PassingYard_Points': 74.8,
#    'Passing_TD_Points': 28.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 319.0,
#    'PassingYard_Points': 89.68,
#    'Passing_TD_Points': 68.0,
#    'Rush_TD_Points': 48},
#   {'Fantasy_Points': 250.0,
#    'PassingYard_Points': 102.48,
#    'Passing_TD_Points': 64.0,
#    'Rush_TD_Points': 24}],
#  'Justin Herbert': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 384.0,
#    'PassingYard_Points': 173.44,
#    'Passing_TD_Points': 124.0,
#    'Rush_TD_Points': 30},
#   {'Fantasy_Points': 442.0,
#    'PassingYard_Points': 200.56,
#    'Passing_TD_Points': 152.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 320.0,
#    'PassingYard_Points': 189.56,
#    'Passing_TD_Points': 100.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 265.0,
#    'PassingYard_Points': 125.36,
#    'Passing_TD_Points': 80.0,
#    'Rush_TD_Points': 18}],
#  'Kellen Mond': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.2,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Kenny Pickett': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 152.0,
#    'PassingYard_Points': 96.16,
#    'Passing_TD_Points': 28.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 114.0,
#    'PassingYard_Points': 82.8,
#    'Passing_TD_Points': 24.0,
#    'Rush_TD_Points': 6}],
#  'Kirk Cousins': [{'Fantasy_Points': 288.0,
#    'PassingYard_Points': 144.12,
#    'Passing_TD_Points': 104.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 370.0,
#    'PassingYard_Points': 170.6,
#    'Passing_TD_Points': 140.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 357.0,
#    'PassingYard_Points': 168.84,
#    'Passing_TD_Points': 132.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 343.0,
#    'PassingYard_Points': 181.88,
#    'Passing_TD_Points': 116.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 184.0,
#    'PassingYard_Points': 93.24,
#    'Passing_TD_Points': 72.0,
#    'Rush_TD_Points': 0}],
#  'Kurt Benkert': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Kyle Allen': [{'Fantasy_Points': 211.0,
#    'PassingYard_Points': 132.88,
#    'Passing_TD_Points': 68.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 50.0,
#    'PassingYard_Points': 24.400000000000002,
#    'Passing_TD_Points': 16.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 10.0,
#    'PassingYard_Points': 4.8,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 20.0,
#    'PassingYard_Points': 16.64,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0}],
#  'Kyle Trask': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.92,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0}],
#  'Kyler Murray': [{'Fantasy_Points': 311.0,
#    'PassingYard_Points': 148.88,
#    'Passing_TD_Points': 80.0,
#    'Rush_TD_Points': 24},
#   {'Fantasy_Points': 418.0,
#    'PassingYard_Points': 158.84,
#    'Passing_TD_Points': 104.0,
#    'Rush_TD_Points': 66},
#   {'Fantasy_Points': 335.0,
#    'PassingYard_Points': 151.48,
#    'Passing_TD_Points': 96.0,
#    'Rush_TD_Points': 30},
#   {'Fantasy_Points': 222.0,
#    'PassingYard_Points': 94.72,
#    'Passing_TD_Points': 56.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 160.0,
#    'PassingYard_Points': 71.96000000000001,
#    'Passing_TD_Points': 40.0,
#    'Rush_TD_Points': 18}],
#  'Lamar Jackson': [{'Fantasy_Points': 474.0,
#    'PassingYard_Points': 125.08,
#    'Passing_TD_Points': 144.0,
#    'Rush_TD_Points': 42},
#   {'Fantasy_Points': 375.0,
#    'PassingYard_Points': 110.28,
#    'Passing_TD_Points': 104.0,
#    'Rush_TD_Points': 42},
#   {'Fantasy_Points': 262.0,
#    'PassingYard_Points': 115.28,
#    'Passing_TD_Points': 64.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 258.0,
#    'PassingYard_Points': 89.68,
#    'Passing_TD_Points': 68.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 370.0,
#    'PassingYard_Points': 147.12,
#    'Passing_TD_Points': 96.0,
#    'Rush_TD_Points': 30}],
#  'Logan Woodside': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 1.0,
#    'PassingYard_Points': 0.28,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': -1.0,
#    'PassingYard_Points': 1.08,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0}],
#  'Luke Falk': [{'Fantasy_Points': 7.0,
#    'PassingYard_Points': 16.64,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Mac Jones': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
# ...
#  'Ryan Finley': [{'Fantasy_Points': 28.0,
#    'PassingYard_Points': 18.96,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 18.0,
#    'PassingYard_Points': 6.5600000000000005,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Ryan Fitzpatrick': [{'Fantasy_Points': 269.0,
#    'PassingYard_Points': 141.16,
#    'Passing_TD_Points': 80.0,
#    'Rush_TD_Points': 24},
#   {'Fantasy_Points': 172.0,
#    'PassingYard_Points': 83.64,
#    'Passing_TD_Points': 52.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.52,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Ryan Griffin': [{'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.72,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Ryan Tannehill': [{'Fantasy_Points': 261.0,
#    'PassingYard_Points': 109.68,
#    'Passing_TD_Points': 88.0,
#    'Rush_TD_Points': 24},
#   {'Fantasy_Points': 395.0,
#    'PassingYard_Points': 152.76,
#    'Passing_TD_Points': 132.0,
#    'Rush_TD_Points': 42},
#   {'Fantasy_Points': 295.0,
#    'PassingYard_Points': 149.36,
#    'Passing_TD_Points': 84.0,
#    'Rush_TD_Points': 42},
#   {'Fantasy_Points': 179.0,
#    'PassingYard_Points': 101.44,
#    'Passing_TD_Points': 52.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 82.0,
#    'PassingYard_Points': 64.64,
#    'Passing_TD_Points': 16.0,
#    'Rush_TD_Points': 6}],
#  'Sam Darnold': [{'Fantasy_Points': 221.0,
#    'PassingYard_Points': 120.96000000000001,
#    'Passing_TD_Points': 76.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 144.0,
#    'PassingYard_Points': 88.32000000000001,
#    'Passing_TD_Points': 36.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 170.0,
#    'PassingYard_Points': 101.08,
#    'Passing_TD_Points': 36.0,
#    'Rush_TD_Points': 30},
#   {'Fantasy_Points': 98.0,
#    'PassingYard_Points': 45.72,
#    'Passing_TD_Points': 28.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 26.0,
#    'PassingYard_Points': 11.88,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 6}],
#  'Sam Ehlinger': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 40.0,
#    'PassingYard_Points': 22.92,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Sam Howell': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 19.0,
#    'PassingYard_Points': 6.76,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 289.0,
#    'PassingYard_Points': 157.84,
#    'Passing_TD_Points': 84.0,
#    'Rush_TD_Points': 30}],
#  'Sean Clifford': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 1.0,
#    'PassingYard_Points': 1.48,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0}],
#  'Sean Mannion': [{'Fantasy_Points': 0.0,
#    'PassingYard_Points': 5.04,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 14.0,
#    'PassingYard_Points': 7.5600000000000005,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Skylar Thompson': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 17.0,
#    'PassingYard_Points': 21.36,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Taylor Heinicke': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 13.0,
#    'PassingYard_Points': 5.48,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 249.0,
#    'PassingYard_Points': 136.76,
#    'Passing_TD_Points': 80.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 138.0,
#    'PassingYard_Points': 74.36,
#    'Passing_TD_Points': 48.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 73.0,
#    'PassingYard_Points': 35.6,
#    'Passing_TD_Points': 20.0,
#    'Rush_TD_Points': 6}],
#  'Taysom Hill': [{'Fantasy_Points': 91.0,
#    'PassingYard_Points': 2.2,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 156.0,
#    'PassingYard_Points': 37.12,
#    'Passing_TD_Points': 16.0,
#    'Rush_TD_Points': 48},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 132.0,
#    'PassingYard_Points': 3.3200000000000003,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 24}],
#  'Teddy Bridgewater': [{'Fantasy_Points': 103.0,
#    'PassingYard_Points': 55.36,
#    'Passing_TD_Points': 36.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 262.0,
#    'PassingYard_Points': 149.32,
#    'Passing_TD_Points': 60.0,
#    'Rush_TD_Points': 30},
#   {'Fantasy_Points': 230.0,
#    'PassingYard_Points': 122.08,
#    'Passing_TD_Points': 72.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 44.0,
#    'PassingYard_Points': 27.32,
#    'Passing_TD_Points': 16.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0}],
#  'Tim Boyle': [{'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.6,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 29.0,
#    'PassingYard_Points': 21.04,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': -3.0,
#    'PassingYard_Points': 1.32,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 11.0,
#    'PassingYard_Points': 14.4,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0}],
#  'Tom Brady': [{'Fantasy_Points': 304.0,
#    'PassingYard_Points': 162.28,
#    'Passing_TD_Points': 96.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 408.0,
#    'PassingYard_Points': 185.32,
#    'Passing_TD_Points': 160.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 454.0,
#    'PassingYard_Points': 212.64000000000001,
#    'Passing_TD_Points': 172.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 319.0,
#    'PassingYard_Points': 187.76,
#    'Passing_TD_Points': 100.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Tommy DeVito': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 104.0,
#    'PassingYard_Points': 44.04,
#    'Passing_TD_Points': 32.0,
#    'Rush_TD_Points': 6}],
#  'Trace McSorley': [{'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.0,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 10.0,
#    'PassingYard_Points': 3.6,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 6.0,
#    'PassingYard_Points': 16.48,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Trevor Lawrence': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 212.0,
#    'PassingYard_Points': 145.64000000000001,
#    'Passing_TD_Points': 48.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 341.0,
#    'PassingYard_Points': 164.52,
#    'Passing_TD_Points': 100.0,
#    'Rush_TD_Points': 30},
#   {'Fantasy_Points': 299.0,
#    'PassingYard_Points': 160.64000000000001,
#    'Passing_TD_Points': 84.0,
#    'Rush_TD_Points': 24}],
#  'Trevor Siemian': [{'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.12,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 108.0,
#    'PassingYard_Points': 46.160000000000004,
#    'Passing_TD_Points': 44.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 11.0,
#    'PassingYard_Points': 7.36,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 29.0,
#    'PassingYard_Points': 28.96,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 0}],
#  'Trey Lance': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 71.0,
#    'PassingYard_Points': 24.12,
#    'Passing_TD_Points': 20.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 11.0,
#    'PassingYard_Points': 7.76,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Tua Tagovailoa': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 149.0,
#    'PassingYard_Points': 72.56,
#    'Passing_TD_Points': 44.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 204.0,
#    'PassingYard_Points': 106.12,
#    'Passing_TD_Points': 64.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 272.0,
#    'PassingYard_Points': 141.92000000000002,
#    'Passing_TD_Points': 100.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 318.0,
#    'PassingYard_Points': 184.96,
#    'Passing_TD_Points': 116.0,
#    'Rush_TD_Points': 0}],
#  'Tyler Bray': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0.0,
#    'PassingYard_Points': 0.72,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Tyler Huntley': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 1.0,
#    'PassingYard_Points': 0.6,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 86.0,
#    'PassingYard_Points': 43.24,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 12},
#   {'Fantasy_Points': 50.0,
#    'PassingYard_Points': 26.32,
#    'Passing_TD_Points': 8.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 28.0,
#    'PassingYard_Points': 8.120000000000001,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 0}],
#  'Tyrod Taylor': [{'Fantasy_Points': 8.0,
#    'PassingYard_Points': 1.32,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 8.0,
#    'PassingYard_Points': 8.32,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 87.0,
#    'PassingYard_Points': 38.64,
#    'Passing_TD_Points': 20.0,
#    'Rush_TD_Points': 18},
#   {'Fantasy_Points': 13.0,
#    'PassingYard_Points': 2.32,
#    'Passing_TD_Points': 4.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 91.0,
#    'PassingYard_Points': 53.64,
#    'Passing_TD_Points': 20.0,
#    'Rush_TD_Points': 0}],
#  'Tyson Bagent': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 58.0,
#    'PassingYard_Points': 34.36,
#    'Passing_TD_Points': 12.0,
#    'Rush_TD_Points': 12}],
#  'Will Grier': [{'Fantasy_Points': 0.0,
#    'PassingYard_Points': 9.120000000000001,
#    'Passing_TD_Points': 0.0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0}],
#  'Will Levis': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 115.0,
#    'PassingYard_Points': 72.32000000000001,
#    'Passing_TD_Points': 32.0,
#    'Rush_TD_Points': 6}],
#  'Zach Wilson': [{'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 0,
#    'PassingYard_Points': 0,
#    'Passing_TD_Points': 0,
#    'Rush_TD_Points': 0},
#   {'Fantasy_Points': 163.0,
#    'PassingYard_Points': 93.36,
#    'Passing_TD_Points': 36.0,
#    'Rush_TD_Points': 24},
#   {'Fantasy_Points': 105.0,
#    'PassingYard_Points': 67.52,
#    'Passing_TD_Points': 24.0,
#    'Rush_TD_Points': 6},
#   {'Fantasy_Points': 132.0,
#    'PassingYard_Points': 90.84,
#    'Passing_TD_Points': 32.0,
#    'Rush_TD_Points': 0}]}

# %%
import json

# Convert the dictionary to JSON format
json_data = json.dumps(name_values_dict, indent=4)

# Write the JSON data to a file
with open('../../Flask/Static/QBYear.json', 'w') as json_file:
    json_file.write(json_data)
