# %%
from pathlib import Path
import pandas as pd

# %%
Complete = Path('../excels/CompleteDataSet.csv')

# %%
CompleteDF = pd.read_csv(Complete)

# %%
CompleteDF.head()
# Out:
#    Unnamed: 0  Week              Name Position  Year     Game  Fantasy Points  \
# 0           0   1.0     Lamar Jackson       QB  2019  BAL@MIA            42.0
# 1           1   1.0      Dak Prescott       QB  2019  NYG@DAL            41.0
# 2           2   1.0    Deshaun Watson       QB  2019   HOU@NO            36.0
# 3           3   1.0  Matthew Stafford       QB  2019  DET@ARI            34.0
# 4           4   1.0       Case Keenum       QB  2019  WAS@PHI            33.0
#
#    PassingYards  PassingTDs  Ints  Rush Attempts  Rush Yards  Fumbles  \
# 0         324.0         5.0     0              3           6        0
# 1         405.0         4.0     0              4          12        0
# 2         268.0         3.0     1              4          40        0
# 3         385.0         3.0     0              3          22        1
# 4         380.0         3.0     0              0           0        0
#
#    RushTDs  Receptions  Receiving Yards  Receiving TDs
# ...

# %%
CompleteDF.drop('Unnamed: 0', axis=1, inplace=True)

# %%
CompleteDF.head()
# Out:
#    Week              Name Position  Year     Game  Fantasy Points  \
# 0   1.0     Lamar Jackson       QB  2019  BAL@MIA            42.0
# 1   1.0      Dak Prescott       QB  2019  NYG@DAL            41.0
# 2   1.0    Deshaun Watson       QB  2019   HOU@NO            36.0
# 3   1.0  Matthew Stafford       QB  2019  DET@ARI            34.0
# 4   1.0       Case Keenum       QB  2019  WAS@PHI            33.0
#
#    PassingYards  PassingTDs  Ints  Rush Attempts  Rush Yards  Fumbles  \
# 0         324.0         5.0     0              3           6        0
# 1         405.0         4.0     0              4          12        0
# 2         268.0         3.0     1              4          40        0
# 3         385.0         3.0     0              3          22        1
# 4         380.0         3.0     0              0           0        0
#
#    RushTDs  Receptions  Receiving Yards  Receiving TDs
# 0        0         NaN              NaN            NaN
# ...

# %%
CompleteDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19979 entries, 0 to 19978
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Week             19345 non-null  float64
#  1   Name             19979 non-null  object
#  2   Position         19979 non-null  object
#  3   Year             19979 non-null  int64
#  4   Game             19979 non-null  object
#  5   Fantasy Points   19979 non-null  float64
#  6   PassingYards     19301 non-null  float64
#  7   PassingTDs       19301 non-null  float64
#  8   Ints             19979 non-null  int64
#  9   Rush Attempts    19979 non-null  int64
#  10  Rush Yards       19979 non-null  int64
#  11  Fumbles          19979 non-null  int64
#  12  RushTDs          19979 non-null  int64
#  13  Receptions       16781 non-null  float64
#  14  Receiving Yards  16781 non-null  float64
#  15  Receiving TDs    16781 non-null  float64
# ...

# %%
CompleteDF = CompleteDF.rename(columns={'Fantasy Points': 'FantasyPoints', 'Rush Attempts': 'RushAttemps', 'Rush Yards': 'RushYards', 'Receiving Yards': 'ReceivingYards', 'Receiving TDs': 'ReceivingTDs'})

# %%
CompleteDF
# Out:
#        Week              Name Position  Year     Game  FantasyPoints  \
# 0       1.0     Lamar Jackson       QB  2019  BAL@MIA           42.0
# 1       1.0      Dak Prescott       QB  2019  NYG@DAL           41.0
# 2       1.0    Deshaun Watson       QB  2019   HOU@NO           36.0
# 3       1.0  Matthew Stafford       QB  2019  DET@ARI           34.0
# 4       1.0       Case Keenum       QB  2019  WAS@PHI           33.0
# ...     ...               ...      ...   ...      ...            ...
# 19974  18.0     Calvin Austin       WR  2023  PIT@BAL            0.0
# 19975  18.0        A.J. Brown       WR  2023  PHI@NYG            0.0
# 19976  18.0       Dyami Brown       WR  2023  DAL@WAS            0.0
# 19977  18.0    George Pickens       WR  2023  PIT@BAL            0.0
# 19978  18.0   KaVontae Turpin       WR  2023  DAL@WAS            0.0
#
#        PassingYards  PassingTDs  Ints  RushAttemps  RushYards  Fumbles  \
# ...

# %%
CompleteDF.to_csv('CompleteDataSetFinal.csv')
